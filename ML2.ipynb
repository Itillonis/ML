# %%
import requests
import yfinance as yf
import pandas as pd
from datetime import timedelta
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression as lr
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.ensemble import GradientBoostingRegressor as GBR

# %%
df = yf.download('EURRUB=X')
df = df.Close.copy()
rates = pd.DataFrame(df).reset_index()
rates.set_index('Date', inplace = True)
rates
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Close
# Date
# 2003-12-01  35.509998
# 2003-12-02  35.880001
# 2003-12-03  35.980000
# 2003-12-04  35.840000
# 2003-12-05  36.080002
# ...               ...
# 2022-09-30  55.341202
# 2022-10-03  56.449402
# 2022-10-04  56.627602
# 2022-10-05  57.857399
# 2022-10-07  58.497799
#
# [4423 rows x 1 columns]

# %%
def make_features(data, max_lag, rolling_mean_size):
    data['year'] = data.index.year
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['is_weekend'] = data.index.isin([5,6])*1
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['Close'].shift(lag)

    data['y_mean'] = data['Close'].shift().rolling(rolling_mean_size).mean().copy()

# %%
make_features(rates,30,3)

# %%
rates.dropna(inplace = True)
rates
# Out:
#                 Close  year  month  day  dayofweek  is_weekend      lag_1  \
# Date
# 2004-01-12  36.799999  2004      1   12          0           0  37.186901
# 2004-01-13  36.900002  2004      1   13          1           0  36.799999
# 2004-01-14  36.520000  2004      1   14          2           0  36.900002
# 2004-01-15  36.369999  2004      1   15          3           0  36.520000
# 2004-01-16  35.676498  2004      1   16          4           0  36.369999
# ...               ...   ...    ...  ...        ...         ...        ...
# 2022-09-30  55.341202  2022      9   30          4           0  54.529202
# 2022-10-03  56.449402  2022     10    3          0           0  55.341202
# 2022-10-04  56.627602  2022     10    4          1           0  56.449402
# 2022-10-05  57.857399  2022     10    5          2           0  56.627602
# 2022-10-07  58.497799  2022     10    7          4           0  57.857399
#
#                 lag_2      lag_3      lag_4  ...     lag_22     lag_23  \
# Date                                         ...
# 2004-01-12  37.150002  36.950001  37.189999  ...  35.919998  35.959999
# 2004-01-13  37.186901  37.150002  36.950001  ...  36.070000  35.919998
# 2004-01-14  36.799999  37.186901  37.150002  ...  36.160000  36.070000
# 2004-01-15  36.900002  36.799999  37.186901  ...  36.029999  36.160000
# 2004-01-16  36.520000  36.900002  36.799999  ...  36.270000  36.029999
# ...               ...        ...        ...  ...        ...        ...
# 2022-09-30  55.318001  55.153000  56.037498  ...  59.687599  59.453098
# 2022-10-03  54.529202  55.318001  55.153000  ...  58.868000  59.687599
# 2022-10-04  55.341202  54.529202  55.318001  ...  60.115898  58.868000
# 2022-10-05  56.449402  55.341202  54.529202  ...  59.981701  60.115898
# 2022-10-07  56.627602  56.449402  55.341202  ...  59.597401  59.981701
#
#                lag_24     lag_25     lag_26     lag_27     lag_28     lag_29  \
# Date
# 2004-01-12  36.169998  36.090000  36.080002  35.840000  35.980000  35.880001
# 2004-01-13  35.959999  36.169998  36.090000  36.080002  35.840000  35.980000
# 2004-01-14  35.919998  35.959999  36.169998  36.090000  36.080002  35.840000
# 2004-01-15  36.070000  35.919998  35.959999  36.169998  36.090000  36.080002
# 2004-01-16  36.160000  36.070000  35.919998  35.959999  36.169998  36.090000
# ...               ...        ...        ...        ...        ...        ...
# 2022-09-30  59.096001  58.630501  59.022099  57.650799  59.060001  59.720001
# 2022-10-03  59.453098  59.096001  58.630501  59.022099  57.650799  59.060001
# 2022-10-04  59.687599  59.453098  59.096001  58.630501  59.022099  57.650799
# 2022-10-05  58.868000  59.687599  59.453098  59.096001  58.630501  59.022099
# 2022-10-07  60.115898  58.868000  59.687599  59.453098  59.096001  58.630501
#
#                lag_30     y_mean
# Date
# 2004-01-12  35.509998  37.095634
# 2004-01-13  35.880001  37.045634
# 2004-01-14  35.980000  36.962301
# 2004-01-15  35.840000  36.740000
# 2004-01-16  36.080002  36.596667
# ...               ...        ...
# 2022-09-30  60.292301  55.000067
# 2022-10-03  59.720001  55.062801
# 2022-10-04  59.060001  55.439935
# 2022-10-05  57.650799  56.139402
# 2022-10-07  59.022099  56.978134
#
# [4393 rows x 37 columns]

# %%
X_train,X_test, y_train, y_test = train_test_split(rates.drop('Close',axis=1),
                                                  rates.Close,
                                                  shuffle = False,
                                                  test_size = 0.2)

# %%
clf = lr()
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = clf.predict(X_test)

# %%
print('Ошибка на обучающей выборке:',MAE(y_train,clf.predict(X_train)), '\nОшибка на тестовой выборке:',MAE(y_test,prediction))
# Out:
# Ошибка на обучающей выборке: 0.41558923941822834
# Ошибка на тестовой выборке: 1.0537491941524004

# %% [markdown]
# ### Предсказание на T+1

# %%
df_new = pd.DataFrame(rates['Close']).reset_index().copy()

# %%
df_new
# Out:
#            Date      Close
# 0    2004-01-12  36.799999
# 1    2004-01-13  36.900002
# 2    2004-01-14  36.520000
# 3    2004-01-15  36.369999
# 4    2004-01-16  35.676498
# ...         ...        ...
# 4388 2022-09-30  55.341202
# 4389 2022-10-03  56.449402
# 4390 2022-10-04  56.627602
# 4391 2022-10-05  57.857399
# 4392 2022-10-07  58.497799
#
# [4393 rows x 2 columns]

# %%
next_day = df_new.tail(1).copy()
next_day['Date'] = next_day['Date'] + timedelta(days=1)
next_day['Close'] = 0
next_day.set_index('Date', inplace = True)
next_day.reset_index(inplace = True)

# %%
next_day
# Out:
#         Date  Close
# 0 2022-10-08      0

# %%
df2 = pd.concat([df_new,next_day], ignore_index=True)
df2.set_index('Date', inplace = True)
df2
# Out:
#                 Close
# Date
# 2004-01-12  36.799999
# 2004-01-13  36.900002
# 2004-01-14  36.520000
# 2004-01-15  36.369999
# 2004-01-16  35.676498
# ...               ...
# 2022-10-03  56.449402
# 2022-10-04  56.627602
# 2022-10-05  57.857399
# 2022-10-07  58.497799
# 2022-10-08   0.000000
#
# [4394 rows x 1 columns]

# %%
make_features(df2,30,3)
df2
# Out:
#                 Close  year  month  day  dayofweek  is_weekend      lag_1  \
# Date
# 2004-01-12  36.799999  2004      1   12          0           0        NaN
# 2004-01-13  36.900002  2004      1   13          1           0  36.799999
# 2004-01-14  36.520000  2004      1   14          2           0  36.900002
# 2004-01-15  36.369999  2004      1   15          3           0  36.520000
# 2004-01-16  35.676498  2004      1   16          4           0  36.369999
# ...               ...   ...    ...  ...        ...         ...        ...
# 2022-10-03  56.449402  2022     10    3          0           0  55.341202
# 2022-10-04  56.627602  2022     10    4          1           0  56.449402
# 2022-10-05  57.857399  2022     10    5          2           0  56.627602
# 2022-10-07  58.497799  2022     10    7          4           0  57.857399
# 2022-10-08   0.000000  2022     10    8          5           0  58.497799
#
#                 lag_2      lag_3      lag_4  ...     lag_22     lag_23  \
# Date                                         ...
# 2004-01-12        NaN        NaN        NaN  ...        NaN        NaN
# 2004-01-13        NaN        NaN        NaN  ...        NaN        NaN
# 2004-01-14  36.799999        NaN        NaN  ...        NaN        NaN
# 2004-01-15  36.900002  36.799999        NaN  ...        NaN        NaN
# 2004-01-16  36.520000  36.900002  36.799999  ...        NaN        NaN
# ...               ...        ...        ...  ...        ...        ...
# 2022-10-03  54.529202  55.318001  55.153000  ...  58.868000  59.687599
# 2022-10-04  55.341202  54.529202  55.318001  ...  60.115898  58.868000
# 2022-10-05  56.449402  55.341202  54.529202  ...  59.981701  60.115898
# 2022-10-07  56.627602  56.449402  55.341202  ...  59.597401  59.981701
# 2022-10-08  57.857399  56.627602  56.449402  ...  59.548599  59.597401
#
#                lag_24     lag_25     lag_26     lag_27     lag_28     lag_29  \
# Date
# 2004-01-12        NaN        NaN        NaN        NaN        NaN        NaN
# 2004-01-13        NaN        NaN        NaN        NaN        NaN        NaN
# 2004-01-14        NaN        NaN        NaN        NaN        NaN        NaN
# 2004-01-15        NaN        NaN        NaN        NaN        NaN        NaN
# 2004-01-16        NaN        NaN        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2022-10-03  59.453098  59.096001  58.630501  59.022099  57.650799  59.060001
# 2022-10-04  59.687599  59.453098  59.096001  58.630501  59.022099  57.650799
# 2022-10-05  58.868000  59.687599  59.453098  59.096001  58.630501  59.022099
# 2022-10-07  60.115898  58.868000  59.687599  59.453098  59.096001  58.630501
# 2022-10-08  59.981701  60.115898  58.868000  59.687599  59.453098  59.096001
#
#                lag_30     y_mean
# Date
# 2004-01-12        NaN        NaN
# 2004-01-13        NaN        NaN
# 2004-01-14        NaN        NaN
# 2004-01-15        NaN  36.740000
# 2004-01-16        NaN  36.596667
# ...               ...        ...
# 2022-10-03  59.720001  55.062801
# 2022-10-04  59.060001  55.439935
# 2022-10-05  57.650799  56.139402
# 2022-10-07  59.022099  56.978134
# 2022-10-08  58.630501  57.660933
#
# [4394 rows x 37 columns]

# %%
lr_full = lr()
lr_full.fit(rates.drop('Close',axis=1),rates.Close)
# Out:
# LinearRegression()

# %%
gb = GBR()
gb.fit(rates.drop('Close',axis=1),rates.Close)
# Out:
# GradientBoostingRegressor()

# %%
print('Предсказание на следующий день - ',clf.predict(df2.drop('Close',axis=1).tail(1))[0].round(4))
print('Предсказание на следующий день по полному датасету - ',lr_full.predict(df2.drop('Close',axis=1).tail(1))[0].round(4))
print('Предсказание на следующий день с помощью GradientBoostingRegressor - ',gb.predict(df2.drop('Close',axis=1).tail(1))[0].round(4))
# Out:
# Предсказание на следующий день -  58.1629
# Предсказание на следующий день по полному датасету -  58.5447
# Предсказание на следующий день с помощью GradientBoostingRegressor -  59.2347
